# %%
with open('./text_raw/negnegnegneg.txt') as outfile:
    text_neg = outfile.readlines()
with open('./text_raw/pospospospos.txt') as outfile:
    text_pos = outfile.readlines()

# %%
len(text_neg)
# Out:
# 47756

# %%
for i in text_neg:
    print(i)
# Out:
# 	0
#
# 公司	15592
#
# 疫情	14900
#
# 市場	12672
#
# 營收	11156
#
# 億元	10869
#
# 股價	10743
#
# 影響	9112
#
# 美國	8844
#
# 今年	8170
#
# 表示	7699
#
# 全球	7382
#
# 中國	7307
#
# 台灣	7208
#
# 投資	6847
#
# 指數	6777
#
# 肺炎	6722
#
# 去年	6702
#
# 需求	6579
#
# 成長	6479
#
# 台股	6376
#
# 外資	6349
#
# 持續	6233
#
# 經濟	6077
#
# 目前	5921
#
# 早盤	5684
#
# 美元	5376
#
# 報導	5071
#
# 表現	4979
#
# 產品	4972
#
# 營運	4934
#
# 預期	4863
#
# 法人	4700
#
# 大陸	4645
#
# 價格	4588
#
# 台積電	4481
#
# 產業	4409
#
# 獲利	4385
#
# 相關	4288
#
# 指出	4260
#
# 台北	4219
#
# 企業	4072
#
# 主要	3967
#
# 上漲	3936
#
# 新冠	3859
#
# 出現	3637
#
# 每股	3612
#
# 增加	3589
#
# 現金	3548
#
# 包括	3539
#
# 國際	3529
#
# 下跌	3522
#
# 手機	3430
#
# 武漢	3400
#
# 買超	3328
#
# 衝擊	3283
#
# 客戶	3276
#
# 認為	3249
#
# 未來	3197
#
# 防疫	3111
#
# 億美	3097
#
# 股票	3089
#
# 生產	3056
#
# 股市	3043
#
# 可望	2949
#
# 減少	2913
#
# 業務	2911
#
# 時報	2897
#
# 受到	2879
#
# 訂單	2859
#
# 預估	2858
#
# 超過	2857
#
# 更多	2782
#
# 記者	2781
#
# 基金	2759
#
# 交易	2746
#
# 股份	2737
#
# 今日	2724
#
# 投資人	2686
#
# 資金	2664
#
# 年增	2653
#
# 金融	2652
#
# 政府	2648
#
# ...

# %%
X = text_neg[30:-42000]

# %%
[X[1].split('\t')[0],int(X[1].split('\t')[1].split('\n')[0])]
# Out:
# ['預期', 4863]

# %%
import pandas as pd
