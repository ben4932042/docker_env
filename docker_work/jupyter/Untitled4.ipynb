# %%
import pandas as pd

# %%
A = ['a','b','c','d']
[A[i] for i in range(len(A))]
# Out:
# ['a', 'b', 'c', 'd']

# %%
df = pd.DataFrame([1,2,3],['a','b','c'])

# %%
df = df.reset_index(drop=False)

# %%
df = df.
# Out:
#   index  0
# 0     a  1
# 1     b  2
# 2     c  3

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-2da19368155f> in <module>()
# ----> 1 [[df.iloc[i][0],df.iloc[i][1],df.iloc[i][1]] for i in range(len(df))]
#
# <ipython-input-10-2da19368155f> in <listcomp>(.0)
# ----> 1 [[df.iloc[i][0],df.iloc[i][1],df.iloc[i][1]] for i in range(len(df))]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
# ...

# %%
df = pd.read_csv('./googlename.csv')

# %%
[
 [df.iloc[i][0],df.iloc[i][1],df.iloc[i][1],df.iloc[i][2],df.iloc[i][2]+'+推薦']
 for i in range(len(df))
]
# Out:
# [['3C', '光學', '光學', '三腳架', '三腳架+推薦'],
#  ['3C', '光學', '光學', '自拍架', '自拍架+推薦'],
#  ['3C', '光學', '光學', '自拍棒', '自拍棒+推薦'],
#  ['3C', '光學', '光學', '自拍鏡頭', '自拍鏡頭+推薦'],
#  ['3C', '光學', '光學', '即可拍相機', '即可拍相機+推薦'],
#  ['3C', '光學', '光學', '空拍飛行機', '空拍飛行機+推薦'],
#  ['3C', '光學', '光學', '相機底片', '相機底片+推薦'],
#  ['3C', '光學', '光學', '相機背帶', '相機背帶+推薦'],
#  ['3C', '光學', '光學', '相機閃光燈', '相機閃光燈+推薦'],
#  ['3C', '光學', '光學', '相機袋', '相機袋+推薦'],
#  ['3C', '光學', '光學', '相機殼', '相機殼+推薦'],
#  ['3C', '光學', '光學', '相機鏡頭', '相機鏡頭+推薦'],
#  ['3C', '光學', '光學', '望遠鏡', '望遠鏡+推薦'],
#  ['3C', '光學', '光學', '數位相機', '數位相機+推薦'],
#  ['3C', '光學', '光學', '遮光罩', '遮光罩+推薦'],
#  ['3C', '光學', '光學', '濾鏡', '濾鏡+推薦'],
#  ['3C', '光學', '光學', '攝影機', '攝影機+推薦'],
#  ['3C', '事務機', '事務機', '3D 印表機', '3D 印表機+推薦'],
#  ['3C', '事務機', '事務機', '印表機', '印表機+推薦'],
#  ['3C', '事務機', '事務機', '印表機碳粉', '印表機碳粉+推薦'],
#  ['3C', '事務機', '事務機', '色帶', '色帶+推薦'],
#  ['3C', '事務機', '事務機', '掃描機', '掃描機+推薦'],
#  ['3C', '事務機', '事務機', '傳真機', '傳真機+推薦'],
# ...
