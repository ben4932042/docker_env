# %%
import pandas as pd

# %%
url = 'https://quality.data.gov.tw/dq_download_json.php?nid=18419&md5_url=9791ec942cbcb925635aa5612ae95588'
df1 = pd.read_json(url)\
        .drop(['上市日期','代理發言人','出表日期','普通股每股面額','外國企業註冊地國','總機電話','網址','英文簡稱','過戶地址','過戶電話','電子郵件信箱'],axis = 1)\
        .drop(['發言人','發言人職稱','總經理','英文通訊地址','特別股','營利事業統一編號','私募股數','簽證會計師1','簽證會計師2','編制財務報表類型'],axis = 1)

# %%
df1.to_csv('./public_stock_basic.csv')

# %%
url = 'https://quality.data.gov.tw/dq_download_json.php?nid=25036&md5_url=1aae8254db1d14b0d113dd93f2265d06'
df2 = pd.read_json(url)\
        .drop(['上市日期','代理發言人','出表日期','普通股每股面額','外國企業註冊地國','總機電話','網址','英文簡稱','過戶地址','過戶電話','電子郵件信箱'],axis = 1)\
        .drop(['發言人','發言人職稱','總經理','英文通訊地址','特別股','營利事業統一編號','私募股數','簽證會計師1','簽證會計師2','編制財務報表類型'],axis = 1)

# %%
df2.to_csv('./counter_stock_basic.csv')

# %%
df2
# Out:
#                                                     住址          傳真機號碼    公司代號  \
# 0                                       台北市和平西路一段三十號二樓    02-23640694    1240
# 1                                       台北市中山區松江路51號8樓  (02)2503-4933    1258
# 2                                    台北市中山區松江路156-1號8樓  (02)2567-1692    1259
# 3                                        新北市五股區五權五路31號  (02)2298-2263    1264
# 4                                  高雄市前金區成功一路266號21樓之1   (07)215-5956    1268
# 5                                新北市三重區重新路五段609巷8號5F-3  (02)2999-7900    1333
# 6                                     新北市新莊區五權一路9號5樓之1    02-22994848    1336
# 7                                新北市汐止區大同路一段276之2號4、5樓  (02)2647-9369    1565
# 8                                     高雄市大寮區大發工業區興業路二號     07-7871515    1569
# 9                                        新北市八里區博物館路81號  (02)2619-5618    1570
# 10                                       新北市五股區五權六路23號    02-22981718    1580
# ...

# %%
T = {'a':1}

# %%
pd.Series( T,name='Latitude_and_Longitude').to_frame().reset_index().to_csv('tee')

# %%
with open('test.txt','r') as outfile:
    t = outfile.readline()

# %%
# Out:
# "{'a': 1}"

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-429018418854> in <module>()
# ----> 1 dict(t)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required
